# %%
import scanpy as sc
import squidpy as sq
import numpy as np
import pandas as pd
from anndata import AnnData
import pathlib
import matplotlib.pyplot as plt
import matplotlib as mpl
import skimage
import seaborn as sns
import tangram as tg

sc.logging.print_header()
print(f"squidpy=={sq.__version__}")

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/diskmnt/Projects/Users/chouw/ipykernel_30202/1433977834.py", line 2, in <module>
#     import squidpy as sq
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/squidpy/__init__.py", line 1, in <module>
#     from squidpy import gr, im, pl, read, datasets
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/squidpy/gr/__init__.py", line 7, in <module>
#     from squidpy.gr._ppatterns import co_occurrence, spatial_autocorr
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/squidpy/gr/_ppatterns.py", line 232, in <module>
#     def _occur_count(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/decorators.py", line 241, in wrapper
#     return wrapper(function)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 965, in compile
#     cres = self._compiler.compile(args, return_type)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 125, in compile
#     status, retval = self._compile_cached(args, return_type)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 139, in _compile_cached
#     retval = self._compile_core(args, return_type)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 152, in _compile_core
#     cres = compiler.compile_extra(self.targetdescr.typing_context,
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/compiler.py", line 768, in compile_extra
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/compiler.py", line 418, in __init__
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/base.py", line 267, in refresh
#     """
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/cpu.py", line 69, in load_additional_registries
#     def load_additional_registries(self):
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/cpython/listobj.py", line 16, in <module>
#     from numba.core.utils import cached_property
# ImportError: cannot import name 'cached_property' from 'numba.core.utils' (/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/utils.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1396, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1287, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1055, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 955, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 778, in lines
#     return self._sd.lines
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
import squidpy as sq
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/diskmnt/Projects/Users/chouw/ipykernel_30202/1896701524.py", line 1, in <module>
#     import squidpy as sq
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/squidpy/__init__.py", line 1, in <module>
#     from squidpy import gr, im, pl, read, datasets
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/squidpy/gr/__init__.py", line 7, in <module>
#     from squidpy.gr._ppatterns import co_occurrence, spatial_autocorr
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/squidpy/gr/_ppatterns.py", line 232, in <module>
#     def _occur_count(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/decorators.py", line 241, in wrapper
#     return wrapper(function)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 965, in compile
#     cres = self._compiler.compile(args, return_type)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 125, in compile
#     status, retval = self._compile_cached(args, return_type)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 139, in _compile_cached
#     retval = self._compile_core(args, return_type)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/dispatcher.py", line 152, in _compile_core
#     cres = compiler.compile_extra(self.targetdescr.typing_context,
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/compiler.py", line 768, in compile_extra
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/compiler.py", line 417, in __init__
#     self.state.metadata['parfors'] = {}
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/typing/context.py", line 160, in refresh
#     self._load_builtins()
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/typing/context.py", line 421, in _load_builtins
#     self.install_registry(templates.builtin_registry)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/typing/context.py", line 441, in install_registry
#     self.insert_attributes(ftcls(self))
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/typing/templates.py", line 1050, in __init__
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/typing/templates.py", line 1100, in _init_once
#     """
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/typing/templates.py", line 940, in _get_target_registry
#     # that the builtin_registry should contain _just_ the stack allocated
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/base.py", line 267, in refresh
#     """
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/cpu.py", line 69, in load_additional_registries
#     def load_additional_registries(self):
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/cpython/listobj.py", line 16, in <module>
#     from numba.core.utils import cached_property
# ImportError: cannot import name 'cached_property' from 'numba.core.utils' (/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/numba/core/utils.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1396, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1287, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1055, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 955, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/IPython/core/ultratb.py", line 778, in lines
#     return self._sd.lines
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/diskmnt/Projects/Users/chouw/Software/envs/tangram/lib/python3.8/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
